# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {'Disease': ['Fungal infection', 'Allergy', 'GERD', ...],
        'Description': ['Fungal infection is a common skin condition caused by fungi.', 'Allergy is an immune system reaction to a substance in the environment.', 'GERD (Gastroesophageal Reflux Disease) is a digestive disorder that affects the lower esophageal sphincter.', ...]}

df = pd.DataFrame(data)

# %%
data = pd.read_csv('description.csv')

# %%
data.head()
# Out:
#                Disease                                        Description
# 0     Fungal infection  Fungal infection is a common skin condition ca...
# 1              Allergy  Allergy is an immune system reaction to a subs...
# 2                 GERD  GERD (Gastroesophageal Reflux Disease) is a di...
# 3  Chronic cholestasis  Chronic cholestasis is a condition where bile ...
# 4        Drug Reaction  Drug Reaction occurs when the body reacts adve...

# %%
data.tail()
# Out:
#                                    Disease  \
# 36  (vertigo) Paroymsal Positional Vertigo
# 37                                    Acne
# 38                 Urinary tract infection
# 39                               Psoriasis
# 40                                Impetigo
#
#                                           Description
# 36  (Vertigo) Paroxysmal Positional Vertigo is a t...
# 37  Acne is a skin condition that occurs when hair...
# 38  Urinary tract infection is an infection in any...
# 39  Psoriasis is a chronic skin condition characte...
# 40  Impetigo is a highly contagious skin infection...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

# %%
plt.plot(x, y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Simple Sine Wave')
plt.grid(True)
plt.show()

# %%
plt.plot(x, y, linestyle='--', color='red')

# %%
plt.plot(x, y, marker='o', markersize=5)

# %%
plt.plot(x, y, label='sin(x)')
plt.plot(x, np.cos(x), label='cos(x)')
plt.legend()

# %%
plt.scatter(x, y)
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Scatter Plot')
plt.show()

# %%
plt.hist(data, bins=10)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()
